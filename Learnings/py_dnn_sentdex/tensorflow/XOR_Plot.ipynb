# %% [markdown]
# <a href="https://colab.research.google.com/github/loganathan001/AI/blob/master/Learnings/py_dnn_sentdex/tensorflow/XOR_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Conv2D, Convolution2D, MaxPooling2D, Flatten
from keras.optimizers import SGD, Adam, RMSprop, Adadelta
from keras.utils import np_utils
from keras import backend as K

import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')


plt.rcParams['figure.dpi'] = 100
plt.ion()
plt.axis('equal')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
LEN = 3000
xs = np.random.rand(LEN) * 2 - 1
ys = np.random.rand(LEN) * 2 - 1
xvals = [0 if x < 0 else 1 for x in xs ]
yvals = [0 if y < 0 else 1 for y in ys ]


data = [[x,y,xval,yval] for (x,y,xval,yval) in zip(xs,ys,xvals,yvals)]

df = pd.DataFrame(data)


plt.rcParams['figure.dpi'] = 100
plt.ion()
plt.axis('equal')

df.columns = ['X', 'Y', 'XVal', 'YVal']

df['XORVal'] = np.logical_xor(df['XVal'].values, df['YVal'].values)

df_zeroes = df[ df['XORVal'] == False]
df_ones = df[ df['XORVal'] == True]

#print(df_ones.head())

#plt.imshow(im, cmap='gray')
plt.scatter(df_zeroes['X'], df_zeroes['Y'], cmap='yellow')
plt.scatter(df_ones['X'], df_ones['Y'], cmap='blue')


#plt.savefig('digit_img.png')
